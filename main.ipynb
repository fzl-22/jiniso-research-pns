# %% [markdown]
# # 3second

# %%
import requests
import pandas as pd

# %%
URL = "https://3second.co.id/api/product/store"
response = requests.get(URL)
response.raise_for_status()

# %%
data = response.json()

stores = data['data']
parsed_data = [
    {
        "Nama Toko": store['name'],
        "Alamat": store['address'],
        "Provinsi": store['province'],
        "Kota": store['city'],
        "Kecamatan": store['district'],
        "Kelurahan": store['sub_district'],
    }
    for store in stores
]

df = pd.DataFrame(parsed_data)
df
# Out:
#                          Nama Toko  \
# 0    3 SECOND 1 KARAWACI SUPER MAL
# 1              3 SECOND FS LAMPUNG
# 2         3 SECOND TUNJUNGAN PLAZA
# 3     3 SECOND BENGKULU INDAH MALL
# 4           3 SECOND 2 RUKO MALANG
# ..                             ...
# 106         3 SECOND BANDUNG PUSAT
# 107          3 SECOND FS MOJOKERTO
# 108          3 SECOND FS GORONTALO
# 109           3 SECOND FS KATAPANG
# 110        3 SECOND FS TULUNGAGUNG
#
#                                                 Alamat          Provinsi  \
# 0     Jl.Boulevard Diponegoro Lt. UG Supermal Karawaci            Banten
# 1                         Jl. Raden Intan No. 140 ABC            Lampung
# 2    TP 1 Lantai 2 Jl. Jenderal Basuki Rachmat No. ...        Jawa Timur
# 3             Bengkulu Indah Mall Lt Dasar Blok A no 7          Bengkulu
# 4                        Jl. Soekarno Hatta A3 Kav 2-3        Jawa Timur
# ..                                                 ...               ...
# ...

# %%
df.to_excel("3second-analysis.xlsx", index=False)

# %% [markdown]
# # Erigo

# %%
import requests
import pandas as pd
import json

# %%
file_path = './erigo-store.json'

with open(file_path, 'r') as file:
    data = json.load(file)

df = pd.json_normalize(data)

df
# Out:
#    store_id                           name phone whatsapp  \
# 0        43       Aeon JGC - Jakarta Timur
# 1        62             Armada Town Square
# 2         8            Bandung Indah Plaza
# 3        77               BINTARO X CHANGE
# 4        17               Bogor Trade Mall
# ..      ...                            ...   ...      ...
# 81       10  Yogya Grya Pahlawan - Bandung
# 82       11      Yogya Kepatihan - Bandung
# 83       87                    YOGYA SLAWI
# 84        9       Yogya Sunda 60 - Bandung
# 85       84              YOGYA TASIKMALAYA
#
#                                               address  \
# 0   Lantai 2 Pop Up Unit - Jl. Jkt Garden City Bou...
# 1                                UG Depan Celcius\r\n
# 2   GF di depan Fore - Jl. Merdeka No.56, Citarum,...
# 3                             GF Depan Atrium JCO\r\n
# 4   GF Depan Atrium Utama - Jl. Ir. H. Juanda No.6...
# ..                                                ...
# ...

# %%
def get_city_province(address, api_key):
    url = f'https://maps.googleapis.com/maps/api/geocode/json?address={address}&key={api_key}'
    response = requests.get(url)
    data = response.json()
    
    if data['status'] == 'OK':
        city = province = None
        for component in data['results'][0]['address_components']:
            if 'administrative_area_level_2' in component['types']:
                city = component['long_name']
            elif 'administrative_area_level_1' in component['types']:
                province = component['long_name']
        return city, province
    return None, None

# %%
GOOGLE_MAPS_API_KEY = "AIzaSyDdTCQstDMGo6O0kowNKimz1Pw1RmC-Mjk" # API Key sudah dihapus hehe

df[['city', 'province']] = df['address'].apply(lambda x: pd.Series(get_city_province(x, GOOGLE_MAPS_API_KEY)))

df
# Out:
#    store_id                           name phone whatsapp  \
# 0        43       Aeon JGC - Jakarta Timur
# 1        62             Armada Town Square
# 2         8            Bandung Indah Plaza
# 3        77               BINTARO X CHANGE
# 4        17               Bogor Trade Mall
# ..      ...                            ...   ...      ...
# 81       10  Yogya Grya Pahlawan - Bandung
# 82       11      Yogya Kepatihan - Bandung
# 83       87                    YOGYA SLAWI
# 84        9       Yogya Sunda 60 - Bandung
# 85       84              YOGYA TASIKMALAYA
#
#                                               address  \
# 0   Lantai 2 Pop Up Unit - Jl. Jkt Garden City Bou...
# 1                                UG Depan Celcius\r\n
# 2   GF di depan Fore - Jl. Merdeka No.56, Citarum,...
# 3                             GF Depan Atrium JCO\r\n
# 4   GF Depan Atrium Utama - Jl. Ir. H. Juanda No.6...
# ..                                                ...
# ...

# %%
df
# Out:
#    store_id                           name phone whatsapp  \
# 0        43       Aeon JGC - Jakarta Timur
# 1        62             Armada Town Square
# 2         8            Bandung Indah Plaza
# 3        77               BINTARO X CHANGE
# 4        17               Bogor Trade Mall
# ..      ...                            ...   ...      ...
# 81       10  Yogya Grya Pahlawan - Bandung
# 82       11      Yogya Kepatihan - Bandung
# 83       87                    YOGYA SLAWI
# 84        9       Yogya Sunda 60 - Bandung
# 85       84              YOGYA TASIKMALAYA
#
#                                               address  \
# 0   Lantai 2 Pop Up Unit - Jl. Jkt Garden City Bou...
# 1                                UG Depan Celcius\r\n
# 2   GF di depan Fore - Jl. Merdeka No.56, Citarum,...
# 3                             GF Depan Atrium JCO\r\n
# 4   GF Depan Atrium Utama - Jl. Ir. H. Juanda No.6...
# ..                                                ...
# ...

# %%
df.to_excel("erigo-analysis.xlsx", index=False)
